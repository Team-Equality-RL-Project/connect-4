# %% [markdown]
# ## CMPE 260 Reinforcement Learning
# ####  Project: Connect Four
#
# ####  Project Summary:
# Connect Four is a two player game in which players select different colored circular pieces, take turns to drop them in a
# 6x7 grid. The first player to place four of their pieces consecutively in a row, column, or a diagonal line wins. A
# computer’s agent can learn to play Connect Four using reinforcement learning techniques, compete against human opponents
# and place pieces to win the game.
#
# #### Team Members: Abhishek Bais, Haley Feng, Princy Joy, Shannon Phu
#
# #### Game Details
# The game can be played in three modes, namely
#    1. SinglePlayer Mode - Human Player vs QLearning Player
#    2. MultiPlayer Mode  - Human Player vs Human Player
#    3. Trainer Mode      - Computer Player vs Computer Player
#
#    where,
#    1. Human Player    - Accepts user input
#    2. Computer Player - Is of 5 types namely:
#       i. Random       - Picks next move randomly from available locations
#      ii. QLearner     - Picks next move based on QLearning
#     iii. SarsaLearner - Picks next move based on SarsaLearning
#      iv. MonteCarlo   - Picks next move based on MonteCarlo algorithm
#       v. Minimax      - Picks next move based on Minimax algorithm
#
# Baseline hyper parameters for QLearner, SarsaLearner players are
#    1. QLearner, SarsaLearner epsilon - 0.2
#    2. QLearner, SarsaLearner alpha   - 0.3
#    3. QLearner, SarsaLearner gamma   - 0.9
#
# Sensitivity Analysis via hyper parameter tuning is performed on QLeaner in battles against Random Move player with
#    1. alpha   = [0.05, 0.25, 0.5, 0.75], epsilon = 0.2, gamma = 0.9
#    2. gamma   = [0.25, 0.5, 0.75, 0.98], epsilon = 0.2, alpha = 0.3
#
# The algorithms used by different Computer Players are briefly described below
#    1. QLearner
#       Uses a reinforcement learning off-policy value based scheme based on the Bellman's equation to learn value of optimal
#       policy regardless of action
#
#    2. SarsaLearner
#       Uses a reinforcement learning on-policy value based scheme to learn the value of the optimal policy based on action
#       derived from the current policy
#
#    3. MonteCarlo
#       Uses Reinforcement Learning to learn directly game experiences without using any prior Markov Decision Process knowledge
#
#    4. Minimax algorithm
#       Minimax algorithm is a recursive algorithm which is used in decision-making and game theory especially in AI game. It
#       provides optimal moves for the player, assuming that the opponent is also playing optimally. For example, considering two
#       opponents: Max and Min playing. Max will try to maximize the value, while Min will choose whatever value is the minimum.
#       The algorithm performs a depth-first search (DFS) which means it will explore the complete game tree as deep as possible,
#       all the way down to the leaf nodes.
#
# #### References:
# 1. https://github.com/ShekMaha/connect4-reinforcement-learning
# 2. https://github.com/KeithGalli/Connect4-Python

# %% [markdown]
# ### 1.0 Define global variables
# The Connect4_Globals.py defines the global variables used by the game.
#
# It includes
# 1. Board size
# 2. Color of coins

# %% [markdown]
# ### 2.0 Define utility classes
# The Connect4_Utilities.py defines utlity classes used by the game.
#
# It includes
# 1. Slot                -  A position on the board
# 2. Board               -  The 6x7 connect 4 playground
# 3. Coin                -  A piece to play the game
# 4. SlotTrackerNode     -  A class that represents a internal node in the graph representation of the board
# 5. ColumnFullException -  A class used to throw exceptions should coins drop in filled board positions

# %% [markdown]
# ### 3.0 Define players who can play the game
# The Connect4_Players.py defines the players who can play the game.
# The Connect4_RLPlayers.py defines the types of computer players who can play the game.
#
# It includes
# 1. Human Player     - Accepts user input
# 2. Computer Player  - Is of 5 types namely:
#     i.   Random     - Picks next move randomly from available locations
#    ii.  QLearner    - Picks next move based on QLearning
#   iii. SarsaLearner - Picks next move based on SarsaLearning
#    iv.  MonteCarlo  - Picks next move based on MonteCarlo algorithm
#     v.   Minimax    - Picks next move based on Minimax algorithm

# %% [markdown]
# ### 4.0 Define the game logic: winning conditions
# The Connect4_GameLogic.py defines the game logic.
#
# It includes
# 1. Game winning condition - A sequence of 4 coins in a row (horizontal, vertical or diagonal)
# 2. Game state             - Check whether the game is over?
# 3. Game outcome           - Determine who won the game (red coin or blue coin) player or tie

# %% [markdown]
# ### 5.0 Setup the game view
# The Connect4_GameView.py configures the game.
#
# It includes
# 1. Game Menu           - The game graphic
# 2. Game Play Mode      - Pick the mode of play (SingePlayer, MultiPlayer or Trainer)
# 3. Game Setup and Play - Sets up the game between players and starts the game

# %%
from Connect4_Globals import *
from Connect4_GameView import GameView
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 6.0 Play the game
# The following battles will be performed between different players.
# For each of these games the different Computer Players will be configured with default hyper parameters
# 1. Qlearner     vs Random Move Player
# 2. SarsaLearner vs Random Move Player
# 3. Qlearner     vs SarsaLeaner Player
# 4. MonteCarlo   vs Random Move Player
# 5. MonteCarlo   vs Qlearner Player
# 6. MonteCarlo   vs SarsaLearner Player
# 7. Minimax      vs Random Move Player
# 8. Minimax      vs Qlearner Player
# 9. Minimax      vs SarsaLearner Player
# 10. Minimax      vs MonteCarlo Player

# %%
#### 6.1 QLearner vs Random Move Player battle over 100 games
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.55
# Player 2 Win Rate:  0.44
# Average game play in 0.242227 seconds.

# %%
#### 6.2 SarsaLearner vs Random Move Player battle over 100 games
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.53
# Player 2 Win Rate:  0.47
# Average game play in 0.065625 seconds.

# %%
#### 6.3 Qlearner vs SarsaLearner battle over 100 games
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "sarsalearner"
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.25
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma)
# Out:
# Player 1 Win Rate:  0.44
# Player 2 Win Rate:  0.55
# Average game play in 0.063437 seconds.

# %%
#### 6.4 MonteCarlo Player vs Random Move Player battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.65
# Player 2 Win Rate:  0.35
# Average game play in 29.055815 seconds.

# %%
#### 6.5 MonteCarlo Player vs Qlearner battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "qlearner"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.65
# Player 2 Win Rate:  0.35
# Average game play in 24.138663 seconds.

# %%
#### 6.6 MonteCarlo Player vs SarsaLearner battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "sarsalearner"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.25
# Player 2 Win Rate:  0.75
# Average game play in 26.117447 seconds.

# %%
#### 6.7 Minimax Player vs Random Move Player battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "minimax" # with depth 5
    PlayerType_2 = "random" 
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.8
# Player 2 Win Rate:  0.2
# Average game play in 5.728731 seconds.

# %%
#### 6.8 Minimax Player vs Qlearner battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "minimax"
    PlayerType_2 = "qlearner"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.7
# Player 2 Win Rate:  0.3
# Average game play in 7.835938 seconds.

# %%
#### 6.9 Minimax Player vs SarsaLearner battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "minimax"
    PlayerType_2 = "sarsalearner"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.25
# Player 2 Win Rate:  0.75
# Average game play in 8.575781 seconds.

# %%
#### 6.9 Minimax Player vs Monte Carlo battle over 20 games
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "minimax"
    PlayerType_2 = "montecarlo"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games)
# Out:
# Player 1 Win Rate:  0.4
# Player 2 Win Rate:  0.6
# Average game play in 18.661736 seconds.

# %% [markdown]
# ### 7.0 Sensitivity analysis of Computer Players
# The following battles will be performed for different values of hyperparamers
# 1. Qlearner vs Random Move Player for different hyper params (alpha, gamma)
# 2. SarsaLearner vs Random Move Player for different hyper params (alpha, gamma)

# %% [markdown]
# #### 7.1 Qlearner learning rate alpha senstivity experiments
#    alpha   = [0.05, 0.25, 0.5, 0.75]
#    epsilon = 0.2
#    gamma   = 0.9

# %%
reset_alpha_gamma_tables()

# %%
#### 7.1.1 Qlearner vs Random Move Player battle over 100 games [ alpha = 0.05 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 1
    exp_gamma = 0    
    alpha   = 0.05
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.52
# Player 2 Win Rate:  0.48
# Average game play in 0.062187 seconds.

# %%
#### 7.1.2 Qlearner vs Random Move Player battle over 100 games [ alpha = 0.25 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 2
    exp_gamma = 0    
    alpha   = 0.25
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.45
# Player 2 Win Rate:  0.55
# Average game play in 0.055938 seconds.

# %%
#### 7.1.3 Qlearner vs Random Move Player battle over 100 games [ alpha = 0.5 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 3
    exp_gamma = 0    
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.49
# Player 2 Win Rate:  0.51
# Average game play in 0.054688 seconds.

# %%
#### 7.1.4 Qlearner vs Random Move Player battle over 100 games [ alpha = 0.75 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 4
    exp_gamma = 0    
    alpha   = 0.75
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.51
# Player 2 Win Rate:  0.49
# Average game play in 0.063125 seconds.

# %%
show_alpha_sensitivity()

# %% [markdown]
# #### Inference on learning rate (lr) alpha
# It can be observed that learning happens rapidly for very low values of lr till 50 games, then higher values of lr catchup
# 1. Very low lr = 0.05 causes rapid learning for first few games, then learning becomes more gradual as more games are played
# 2. Low lr = 0.25 causes the most gradual learning
# 3. Moderate lr = 0.5 causes slow learning till about 40 games, then rapid learning takes place
# 2. High lr = 0.75 closely mirrors very low lr = 0.05, learning rapidly initially, then learning more gradually.

# %% [markdown]
# #### 7.2 Qlearner gamma senstivity experiments
#    alpha   = 0.5
#    epsilon = 0.2
#    gamma   = [0.25, 0.5, 0.75, 0.98]

# %%
reset_alpha_gamma_tables()

# %%
#### 7.2.1 Qlearner vs Random Move Player battle over 100 games [ gamma = 0.25 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 1
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.25
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.56
# Player 2 Win Rate:  0.44
# Average game play in 0.063125 seconds.

# %%
#### 7.2.2 Qlearner vs Random Move Player battle over 100 games [ gamma = 0.5 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 2
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.5
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.57
# Player 2 Win Rate:  0.43
# Average game play in 0.063750 seconds.

# %%
#### 7.2.3 Qlearner vs Random Move Player battle over 100 games [ gamma = 0.75 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 3
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.75
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.49
# Player 2 Win Rate:  0.49
# Average game play in 0.067656 seconds.

# %%
#### 7.2.4 Qlearner vs Random Move Player battle over 100 games [ gamma = 0.98 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "qlearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 4
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.98
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.54
# Player 2 Win Rate:  0.46
# Average game play in 0.050937 seconds.

# %%
show_gamma_sensitivity()

# %% [markdown]
# #### Inference on discount  gamma
# It can be observed that that best discount factor = 0.5 for best tuned lr = 0.5
# 1. Low gamma, Moderate gamma = 0.25/ 0.5 appear an optimum discount with consistently high percentage of wins
# 2. High gamma = 0.75 appears to learn more slowly vs lesser or higher discount factors
# 1. Very High gamma = 0.98 learns rapidly for first 20 games then learning rate slows down vs optimum discount rate

# %% [markdown]
# #### 7.3 Sarsalearner learning rate alpha senstivity experiments
#    alpha   = [0.05, 0.25, 0.5, 0.75]
#    epsilon = 0.2
#    gamma   = 0.9

# %%
reset_alpha_gamma_tables()

# %%
#### 7.3.1 Sarsalearner vs Random Move Player battle over 100 games [ alpha = 0.05 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 1
    exp_gamma = 0    
    alpha   = 0.05
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.47
# Player 2 Win Rate:  0.53
# Average game play in 0.068125 seconds.

# %%
#### 7.3.2 Sarsalearner vs Random Move Player battle over 100 games [ alpha = 0.25 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 2
    exp_gamma = 0    
    alpha   = 0.25
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.48
# Player 2 Win Rate:  0.51
# Average game play in 0.067500 seconds.

# %%
#### 7.3.3 Sarsalearner vs Random Move Player battle over 100 games [ alpha = 0.5 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 3
    exp_gamma = 0    
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.61
# Player 2 Win Rate:  0.39
# Average game play in 0.068594 seconds.

# %%
#### 7.3.4 Sarsalearner vs Random Move Player battle over 100 games [ alpha = 0.75 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 4
    exp_gamma = 0    
    alpha   = 0.75
    epsilon = 0.2
    gamma   = 0.9
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.5
# Player 2 Win Rate:  0.5
# Average game play in 0.062344 seconds.

# %%
show_alpha_sensitivity()

# %% [markdown]
# #### Inference on learning rate (lr) alpha
# It can be observed that as lr increases, learning becomes faster till optimum lr = 0.5 is reached. Then learning decreases
# 1. Very low lr = 0.05 appear to learn slowest when compared to moderate or higher learning rates.
# 2. Low lr = 0.25 appear to learn faster than very low learning rates.
# 3. Moderate lr = 0.5 appears as an optimum lr with faster learning when compared to lower or higher learning rates.
# 4. High lr = 0.75 appear to learn gradually and slower than the optimum learning rate.

# %% [markdown]
# #### 7.4 Sarsalearner gamma senstivity experiments
#    alpha   = 0.3
#    epsilon = 0.2
#    gamma   = [0.25, 0.5, 0.75, 0.98]

# %%
reset_alpha_gamma_tables()

# %%
#### 7.4.1 Sarsalearner vs Random Move Player battle over 100 games [ gamma = 0.25 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 1
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.25
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.51
# Player 2 Win Rate:  0.49
# Average game play in 0.065156 seconds.

# %%
#### 7.4.2 Sarsalearner vs Random Move Player battle over 100 games [ gamma = 0.5 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 2
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.5
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.45
# Player 2 Win Rate:  0.54
# Average game play in 0.065625 seconds.

# %%
#### 7.4.3 Sarsalearner vs Random Move Player battle over 100 games [ gamma = 0.75 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 3
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.75
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.39
# Player 2 Win Rate:  0.61
# Average game play in 0.061094 seconds.

# %%
#### 7.4.4 Sarsalearner vs Random Move Player battle over 100 games [ gamma = 0.98 ]
if __name__ == "__main__":
    num_games = 100
    PlayerType_1 = "sarsalearner"
    PlayerType_2 = "random"
    exp_alpha = 0
    exp_gamma = 4
    alpha   = 0.5
    epsilon = 0.2
    gamma   = 0.98
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon, alpha, gamma, exp_alpha, exp_gamma)
# Out:
# Player 1 Win Rate:  0.47
# Player 2 Win Rate:  0.52
# Average game play in 0.077031 seconds.

# %%
show_gamma_sensitivity()

# %% [markdown]
# #### Inference on discount  gamma
# From the plots it can be observed that best discount factor = 0.25 for best tuned lr = 0.5
# 1. Low gamma = 0.25 appears an optimum discount with consistently high percentage of wins.
# 2. Moderate gamma = 0.5 learn gradually and faster than higher gamma values, but slower than lower gamma values.
# 3. High gamma = 0.75 appears to learn more slowly vs lesser or higher discount factors.

# %% [markdown]
# ### Sensitivity analysis on Montecarlo for Exploration Coefficient
# Exploration coefficient values = [0.8, 1, 1.4, 1.6]
#
#
# MCTS keep track of the win ratio and visit count for each node and selects a potential move based on following formula which combines both these values.
#
# $ UCT = X_j + C * \sqrt\frac{\ln(N)}{N_j} $
#
# - $UCT$ - Upper Confidence bounds applied to Trees
# - $X_j$: win ratio for a child node
# - $C$: Exploration coefficient
# - $N$: number of times the parent node has been visited
# - $N_j$: number of times the child node has been visited.
# - $X_j$ represents exploitation, as it is a large value when the win rate is high
# - Second term represents exploration, as it is large when the number of visits for that node have been low.
#
# The tradeoff of exploration-exploitation can be controlled by tuning the value of $C$. A large $C$ value means more exploration, the algorithm gives chance to least explored nodes. A small value $C$ value means more exploitation, here the algorithm will revisit already explored nodes.

# %%
reset_alpha_gamma_tables()

# %%
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon=0.2, alpha=0.3, gamma=0.9, exp_alpha=0, exp_gamma=0, exploration_coeff=0.8)
# Out:
# Player 1 Win Rate:  0.25
# Player 2 Win Rate:  0.75
# Average game play in 37.676563 seconds.

# %%
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon=0.2, alpha=0.3, gamma=0.9, exp_alpha=0, exp_gamma=0, exploration_coeff=1)
# Out:
# Player 1 Win Rate:  0.4
# Player 2 Win Rate:  0.6
# Average game play in 40.642969 seconds.

# %%
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon=0.2, alpha=0.3, gamma=0.9, exp_alpha=0, exp_gamma=0, exploration_coeff=1.4)
# Out:
# Player 1 Win Rate:  0.2
# Player 2 Win Rate:  0.8
# Average game play in 39.372656 seconds.

# %%
if __name__ == "__main__":
    num_games = 20
    PlayerType_1 = "montecarlo"
    PlayerType_2 = "random"
    GameView(1200, 760).main_menu(PlayerType_1, PlayerType_2, num_games, epsilon=0.2, alpha=0.3, gamma=0.9, exp_alpha=0, exp_gamma=0, exploration_coeff=1.6)
# Out:
# Player 1 Win Rate:  0.7
# Player 2 Win Rate:  0.3
# Average game play in 39.906250 seconds.

# %%
show_exp_coeff_sensitivity()

# %% [markdown]
# #### Inference on exploration coefficient
# It can be observed that
# 1. Optimal value of exploration coefficient is 1.6 as it has the highest win ratio.
# 2. The theoretical optimum value for $C$ is $\sqrt{2}$. The sensitivity analysis shows that the theoretical optimum and the observed optimum are reasonably close to each other.
